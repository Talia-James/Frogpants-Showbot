# %%
import os,json,asyncio
from google.auth.transport.requests import Request
import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors
from google.oauth2.credentials import Credentials
from funcs import *
from google_auth_oauthlib.flow import InstalledAppFlow

# %%
api_service_name = "youtube"
api_version = "v3"
client_secrets_file = r"C:/Users/RyuRa/OneDrive/Github/oauth2_credentials.json"
credentials = None

# %%
if not credentials or not credentials.valid:
    if credentials and credentials.expired and credentials.refresh_token:
        credentials.refresh(Request())
    else:
        flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(client_secrets_file,scopes)
        credentials = flow.run_local_server(port=0)
    with open('token.json','w') as token:
        token.write(credentials.to_json())
flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(
    client_secrets_file, scopes)
# credentials = flow.run_local_server()

# %%
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, credentials=credentials)

# %%
async def submit_errors(error):
    print('Farts')

# %%
from random import random
from time import sleep
while True:
    i = random()
    print(random())
    if i>0.8:
        await submit_errors(i)
    sleep(1)
# Out:
# 0.012878807884932897
# 0.9959716844479682
# Farts
# 0.6818792786128439
# 0.4560549257515867
# 0.392119683442975
# Farts
# 0.3312432928112926
# 0.10495596654358863
# 0.10991292072848036
# 0.11213083615023078
# 0.32780745236657405
# 0.5589574600222903
# 0.7516711012468019
# 0.5323533546972086
# 0.5056747784780536
# 0.1297998255584717
# 0.5932653621823665
# 0.40301505392102377
# Farts
# 0.4351156565674219
# Farts
# 0.6880577843893124
# Farts
# 0.34677651328268855
# 0.42718689340200944
# Farts
# 0.5918296662010025
# 0.6216484520348222
# 0.002931057203362175
# 0.13464845952485327
# Farts
# 0.29153213180304804
# 0.07154343448860712
# 0.7446186600586585
# 0.4155481127939177
# Farts
# 0.9249368164294273
# 0.9659367559027112
# 0.260750448887915
# Farts
# 0.05012159093857382
# Farts
# 0.7940684897474194
# 0.18218907400806783
# 0.656578836269022
# 0.7475893646305858
# 0.36658904299027373
# 0.8224891615354376
# 0.40483034071670376
# 0.9056573064618789
# 0.18355476336068388
# 0.6476710421385511
# 0.18017923173296713
# 0.36464274632685834
# 0.5052622078301431
# 0.4794520855194002
# Farts
# 0.3690684588165146
# Farts
# 0.3492225200879677
# 0.19508506449193197
# Farts
# 0.8527967157246734
# 0.23803544847305425
# 0.18889109395676695
# 0.594990820820478
# 0.45264356516583915
# 0.3160771786516162
# 0.6186518546728061
# 0.8109143998681227
# 0.9208882478382157
# 0.8191172719765452
# Farts
# 0.337615795100768
# 0.2653273562679255
# Farts
# 0.06865474521663428
# 0.11525414591499328
# 0.7504284814540191
# 0.4366327112022539
# Farts
# 0.7330604311115015
# Farts
# 0.8309310653319921
# 0.08588874801643165
# 0.7948065921554053
# 0.5593496238318553
# 0.8409828203492355
# 0.3288496516599956
# 0.09579652959589913
# Farts
# 0.7855242589155156
# 0.3678802696595508
# 0.2757284597660782
# 0.5818881110382067
# 0.6968111159270691
# 0.7388174574626892
# 0.1044409698942419
# 0.1488529926563683
# 0.6117963346038928
# 0.6586318048790083
# 0.5184846721454819
# Farts
# 0.8650749411793713
# 0.7367845509451207
# 0.41096184455161944
# 0.24032703315534865
# 0.7687071156795702
# 0.44079933907761415
# 0.7433675000022796
# Farts
# 0.9773423253396716
# 0.1073935323135311
# 0.6011055693329496
# 0.32601103700741374
# 0.9514019668598508
# 0.6236056336245687
# 0.30184914228088333
# 0.678828617770149
# 0.9317309461605761
# 0.669445654048516
# Farts
# 0.0011288260649214843
# 0.4754614849239345
# 0.3728748725173253
# Farts
# 0.5400119890635708
# 0.8553947482747428
# Farts
# 0.6020401198659008
# Farts
# 0.5289626803574463
# Farts
# 0.8157668621534198
# 0.7952082123786506
# Farts
# 0.7716354634889021
# 0.19747220458885506
# 0.6382685444950554
# 0.9259690607065497
# 0.7452444239554994
# 0.13313638963378271
# 0.7545529189525744
# Farts
# 0.2633682233335215
# 0.09026799925287543
# 0.16747323757488197
# 0.8697384506892859
# 0.10094098521817729
# 0.9430228282269265
# Farts
# 0.19256280906920697
# 0.1438611848087371
# Farts
# 0.621477099987343
# 0.7552081597485194
# 0.7566013581011473
